# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('ventas.csv')

print(df.head(3))
print("-" * 30)
print(df.info())
# Out:
#    ID_Transaccion   Ciudad  Venta Categoria_Producto  Precio_Unitario  \
# 0               1  Houston  False               Ropa            89.74
# 1               2  Houston  False               Ropa           109.76
# 2               3  Houston  False               Ropa           106.53
#
#    Cantidad  Total_Venta
# 0         7       628.18
# 1         5       548.80
# 2         8       852.24
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_Transaccion      1003 non-null   int64
#  1   Ciudad              953 non-null    object
#  2   Venta               1003 non-null   bool
#  3   Categoria_Producto  1003 non-null   object
#  4   Precio_Unitario     1003 non-null   float64
#  5   Cantidad            1003 non-null   int64
#  6   Total_Venta         1003 non-null   float64
# ...

# %%
sns.set_style("whitegrid")

# %%
df.head(5)
# Out:
#    ID_Transaccion   Ciudad  Venta Categoria_Producto  Precio_Unitario  \
# 0               1  Houston  False               Ropa            89.74
# 1               2  Houston  False               Ropa           109.76
# 2               3  Houston  False               Ropa           106.53
# 3               4  Houston  False               Ropa           168.24
# 4               5  Houston  False          Alimentos           108.90
#
#    Cantidad  Total_Venta
# 0         7       628.18
# 1         5       548.80
# 2         8       852.24
# 3         3       504.72
# 4         1       108.90

# %%
df.tail(5)
# Out:
#       ID_Transaccion   Ciudad  Venta Categoria_Producto  Precio_Unitario  \
# 998              999  Houston  False               Ropa           173.13
# 999             1000  Houston  False        Electrónica           133.53
# 1000             766  Houston  False               Ropa           133.45
# 1001             506  Houston  False          Alimentos           107.07
# 1002             681  Houston  False        Electrónica           239.76
#
#       Cantidad  Total_Venta
# 998          3       519.39
# 999          2       267.06
# 1000         9      1201.05
# 1001         7       749.49
# 1002         2       479.52

# %%
df.shape
# Out:
# (1003, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_Transaccion      1003 non-null   int64
#  1   Ciudad              953 non-null    object
#  2   Venta               1003 non-null   bool
#  3   Categoria_Producto  1003 non-null   object
#  4   Precio_Unitario     1003 non-null   float64
#  5   Cantidad            1003 non-null   int64
#  6   Total_Venta         1003 non-null   float64
# dtypes: bool(1), float64(2), int64(2), object(2)
# memory usage: 48.1+ KB

# %%
df.dtypes
# Out:
# ID_Transaccion          int64
# Ciudad                 object
# Venta                    bool
# Categoria_Producto     object
# Precio_Unitario       float64
# Cantidad                int64
# Total_Venta           float64
# dtype: object

# %%
df.describe()
# Out:
#        ID_Transaccion  Precio_Unitario     Cantidad  Total_Venta
# count     1003.000000      1003.000000  1003.000000  1003.000000
# mean       500.950150       136.460209     5.072782   690.806510
# std        288.564738        72.139190     2.564475   546.643989
# min          1.000000        24.670000     1.000000    37.210000
# 25%        251.500000        84.400000     3.000000   299.480000
# 50%        502.000000       122.810000     5.000000   552.700000
# 75%        750.500000       172.075000     7.000000   912.220000
# max       1000.000000       660.280000     9.000000  4562.460000

# %%
df.describe(include='object')
# Out:
#          Ciudad Categoria_Producto
# count       953               1003
# unique        1                  4
# top     Houston               Ropa
# freq        953                417

# %%
df.isnull().sum()
# Out:
# ID_Transaccion         0
# Ciudad                50
# Venta                  0
# Categoria_Producto     0
# Precio_Unitario        0
# Cantidad               0
# Total_Venta            0
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# ID_Transaccion        0.000000
# Ciudad                4.985045
# Venta                 0.000000
# Categoria_Producto    0.000000
# Precio_Unitario       0.000000
# Cantidad              0.000000
# Total_Venta           0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(inplace=True)

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
sns.histplot(df['Total_Venta'], kde=True)
plt.title('Distribución de la Venta Total')

plt.subplot(1, 2, 2)
sns.boxplot(y=df['Total_Venta'])
plt.title('Boxplot de la Venta Total')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(y=df['Categoria_Producto'], order=df['Categoria_Producto'].value_counts().index)
plt.title('Conteo de Ventas por Categoría de Producto')
plt.show()

# %%
columnas_numericas = df.select_dtypes(include=['number']).columns
sns.heatmap(df[columnas_numericas].corr(), annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

sns.scatterplot(x='Precio_Unitario', y='Total_Venta', data=df)
plt.title('Precio Unitario vs. Venta Total')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Categoria_Producto', y='Total_Venta', data=df)
plt.title('Venta Total por Categoría de Producto')
plt.show()
